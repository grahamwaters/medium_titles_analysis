# %% [markdown]
# <a href="https://colab.research.google.com/github/icehelmetminer/medium_titles_analysis/blob/dev/listmaker_medium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Links = ["https://opensource.com/downloads/7-essential-pypi-libraries","https://opensource.com/downloads/advanced-ssh-cheat-sheet","https://opensource.com/downloads/ansible-cheat-sheet","https://opensource.com/downloads/ansible-k8s-cheat-sheet","https://opensource.com/downloads/ansible-quickstart","https://opensource.com/downloads/apt-cheat-sheet","https://opensource.com/downloads/awk-ebook","https://opensource.com/downloads/bash-cheat-sheet","https://opensource.com/downloads/bash-programming-guide","https://opensource.com/downloads/bash-scripting-ebook","https://opensource.com/downloads/blender-hotkey-cheat-sheet","https://opensource.com/downloads/c-getopt-cheat-sheet","https://opensource.com/downloads/c-programming-cheat-sheet","https://opensource.com/downloads/chaos-engineering-kubernetes","https://opensource.com/downloads/cheat-sheet-awk-features","https://opensource.com/downloads/cheat-sheet-git","https://opensource.com/downloads/cheat-sheet-gnome-3","https://opensource.com/downloads/cheat-sheet-i3-window-manager-keybinding","https://opensource.com/downloads/cheat-sheet-markdown","https://opensource.com/downloads/cheat-sheet-networking","https://opensource.com/downloads/cheat-sheet-python-37-beginners","https://opensource.com/downloads/cheat-sheet-selinux","https://opensource.com/downloads/cheat-sheet-vim","https://opensource.com/downloads/cheat-sheets","https://opensource.com/downloads/cheat-sheets#main-menu","https://opensource.com/downloads/collaboration-tools-ebook","https://opensource.com/downloads/containers-primer","https://opensource.com/downloads/cout-cheat-sheet","https://opensource.com/downloads/curl-command-cheat-sheet","https://opensource.com/downloads/desktop-tools","https://opensource.com/downloads/devops-hiring-guide","https://opensource.com/downloads/devops-monitoring-guide","https://opensource.com/downloads/devops-transformation","https://opensource.com/downloads/devsecops","https://opensource.com/downloads/dnf-cheat-sheet","https://opensource.com/downloads/dos-conio-cheat-sheet","https://opensource.com/downloads/emacs-cheat-sheet","https://opensource.com/downloads/firewall-cheat-sheet","https://opensource.com/downloads/freedos-commands-cheat-sheet","https://opensource.com/downloads/getting-started-kubernetes-ebook","https://opensource.com/downloads/getting-started-raspberry-pi-cheat-sheet","https://opensource.com/downloads/gnu-debugger-cheat-sheet","https://opensource.com/downloads/gnu-screen-cheat-sheet","https://opensource.com/downloads/go-cheat-sheet","https://opensource.com/downloads/grep-cheat-sheet","https://opensource.com/downloads/groff-macros-cheat-sheet","https://opensource.com/downloads/guide-inter-process-communication-linux","https://opensource.com/downloads/home-automation-ebook","https://opensource.com/downloads/inkscape-cheat-sheet","https://opensource.com/downloads/java-cheat-sheet","https://opensource.com/downloads/java-serverless-ebook","https://opensource.com/downloads/javascript-cheat-sheet","https://opensource.com/downloads/jinja2-cheat-sheet","https://opensource.com/downloads/jupyter-guide","https://opensource.com/downloads/jupyterlab-cheat-sheet","https://opensource.com/downloads/kdenlive-cheat-sheet","https://opensource.com/downloads/kubectl-cheat-sheet","https://opensource.com/downloads/kubernetes-cheat-sheet","https://opensource.com/downloads/kubernetes-raspberry-pi","https://opensource.com/downloads/kubernetes-sysadmin","https://opensource.com/downloads/linux-common-commands-cheat-sheet","https://opensource.com/downloads/linux-cron-cheat-sheet","https://opensource.com/downloads/linux-find-cheat-sheet","https://opensource.com/downloads/linux-permissions-cheat-sheet","https://opensource.com/downloads/linux-systemd-cheat-sheet","https://opensource.com/downloads/linux-wget-cheat-sheet","https://opensource.com/downloads/logrotate-cheat-sheet","https://opensource.com/downloads/lua-cheat-sheet","https://opensource.com/downloads/mariadb-mysql-cheat-sheet","https://opensource.com/downloads/microservices-cheat-sheet","https://opensource.com/downloads/open-source-software-alternatives-cheat-sheet","https://opensource.com/downloads/organization-tools","https://opensource.com/downloads/pandoc-cheat-sheet","https://opensource.com/downloads/parted-cheat-sheet","https://opensource.com/downloads/pip-cheat-sheet","https://opensource.com/downloads/python-3-ebook","https://opensource.com/downloads/python-gaming-ebook","https://opensource.com/downloads/raspberry-pi-guide","https://opensource.com/downloads/rust-cheat-sheet","https://opensource.com/downloads/sed-cheat-sheet","https://opensource.com/downloads/small-scale-scrum","https://opensource.com/downloads/sqlite-cheat-sheet","https://opensource.com/downloads/tmux-cheat-sheet","https://opensource.com/downloads/watch-cheat-sheet","https://opensource.com/downloads/yaml-cheat-sheet"]

# %%
Names = ["7-essential-pypi-libraries","advanced-ssh-cheat-sheet","ansible-cheat-sheet","ansible-k8s-cheat-sheet","ansible-quickstart","apt-cheat-sheet","awk-ebook","bash-cheat-sheet","bash-programming-guide","bash-scripting-ebook","blender-hotkey-cheat-sheet","c-getopt-cheat-sheet","c-programming-cheat-sheet","chaos-engineering-kubernetes","cheat-sheet-awk-features","cheat-sheet-git","cheat-sheet-gnome-3","cheat-sheet-i3-window-manager-keybinding","cheat-sheet-markdown","cheat-sheet-networking","cheat-sheet-python-37-beginners","cheat-sheet-selinux","cheat-sheet-vim","cheat-sheets","cheat-sheets#main-menu","collaboration-tools-ebook","containers-primer","cout-cheat-sheet","curl-command-cheat-sheet","desktop-tools","devops-hiring-guide","devops-monitoring-guide","devops-transformation","devsecops","dnf-cheat-sheet","dos-conio-cheat-sheet","emacs-cheat-sheet","firewall-cheat-sheet","freedos-commands-cheat-sheet","getting-started-kubernetes-ebook","getting-started-raspberry-pi-cheat-sheet","gnu-debugger-cheat-sheet","gnu-screen-cheat-sheet","go-cheat-sheet","grep-cheat-sheet","groff-macros-cheat-sheet","guide-inter-process-communication-linux","home-automation-ebook","inkscape-cheat-sheet","java-cheat-sheet","java-serverless-ebook","javascript-cheat-sheet","jinja2-cheat-sheet","jupyter-guide","jupyterlab-cheat-sheet","kdenlive-cheat-sheet","kubectl-cheat-sheet","kubernetes-cheat-sheet","kubernetes-raspberry-pi","kubernetes-sysadmin","linux-common-commands-cheat-sheet","linux-cron-cheat-sheet","linux-find-cheat-sheet","linux-permissions-cheat-sheet","linux-systemd-cheat-sheet","linux-wget-cheat-sheet","logrotate-cheat-sheet","lua-cheat-sheet","mariadb-mysql-cheat-sheet","microservices-cheat-sheet","open-source-software-alternatives-cheat-sheet","organization-tools","pandoc-cheat-sheet","parted-cheat-sheet","pip-cheat-sheet","python-3-ebook","python-gaming-ebook","raspberry-pi-guide","rust-cheat-sheet","sed-cheat-sheet","small-scale-scrum","sqlite-cheat-sheet","tmux-cheat-sheet","watch-cheat-sheet","yaml-cheat-sheet"]

# %%
startings = [
            'Next up we have ',
           'Next is a',
           'Our next resource is a ',
           'Another good one is the '
           'Check this out --> ',
           'Something you might find useful:'

]
endings = [
           ' ...cheat sheet. ',
           ' ...check it out. ',
           '. This is ',
           '. From what people say, I have heard it is ',
           ' it could be ',
           ' it seems ',
           ' it has mixed reviews but I would like to think that it is '
]
describers = [
              ' interesting ',
              ' well-formed ',
              ' useful ',
              ' (useful?) ',
              ' nice ',
              ' compelling '
]
import random

#intro = f'Next up we have {name} a cheatsheet you may find very useful.'
#intro = f'Next is {name}.'
#intro = f'Next on our list: {name}.'
#intro = f'Next up we have {name} a cheatsheet you may find very useful.'
#intro = f'Next up we have {name} a cheatsheet you may find very useful.'
counter = 0
name = ''

for link_id in range(0,len(Links)):
  link = Links[link_id]
  name = Names[link_id]
  line = f'{counter}. {random.choice(startings)}{name}{random.choice(endings)}{random.choice(describers)}'
  print(line)
  print(link)
  counter += 1
# Out:
# 0. Next is a7-essential-pypi-libraries. This is  useful
# https://opensource.com/downloads/7-essential-pypi-libraries
# 1. Next is aadvanced-ssh-cheat-sheet. From what people say, I have heard it is  compelling
# https://opensource.com/downloads/advanced-ssh-cheat-sheet
# 2. Next up we have ansible-cheat-sheet ...cheat sheet.  nice
# https://opensource.com/downloads/ansible-cheat-sheet
# 3. Another good one is the Check this out --> ansible-k8s-cheat-sheet it seems  useful
# https://opensource.com/downloads/ansible-k8s-cheat-sheet
# 4. Next is aansible-quickstart. From what people say, I have heard it is  interesting
# https://opensource.com/downloads/ansible-quickstart
# 5. Our next resource is a apt-cheat-sheet. This is  interesting
# https://opensource.com/downloads/apt-cheat-sheet
# 6. Next is aawk-ebook ...check it out.  well-formed
# https://opensource.com/downloads/awk-ebook
# ...
